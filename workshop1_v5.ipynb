# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Постановка-задачи" data-toc-modified-id="Постановка-задачи-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Постановка задачи</a></span></li><li><span><a href="#Описание-и-загрузка-данных" data-toc-modified-id="Описание-и-загрузка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание и загрузка данных</a></span></li><li><span><a href="#Предварительная-обработка-данных" data-toc-modified-id="Предварительная-обработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предварительная обработка данных</a></span><ul class="toc-item"><li><span><a href="#make" data-toc-modified-id="make-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>make</a></span></li><li><span><a href="#year" data-toc-modified-id="year-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>year</a></span></li><li><span><a href="#model" data-toc-modified-id="model-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>model</a></span></li><li><span><a href="#trim" data-toc-modified-id="trim-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>trim</a></span><ul class="toc-item"><li><span><a href="#trim-features-keywords" data-toc-modified-id="trim-features-keywords-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>trim features keywords</a></span></li><li><span><a href="#4x4" data-toc-modified-id="4x4-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>4x4</a></span></li><li><span><a href="#special" data-toc-modified-id="special-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>special</a></span></li><li><span><a href="#engine" data-toc-modified-id="engine-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>engine</a></span></li><li><span><a href="#volume" data-toc-modified-id="volume-3.4.5"><span class="toc-item-num">3.4.5&nbsp;&nbsp;</span>volume</a></span></li></ul></li><li><span><a href="#body" data-toc-modified-id="body-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>body</a></span></li><li><span><a href="#transmission" data-toc-modified-id="transmission-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>transmission</a></span></li><li><span><a href="#state" data-toc-modified-id="state-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>state</a></span></li><li><span><a href="#condition" data-toc-modified-id="condition-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>condition</a></span></li><li><span><a href="#odometer" data-toc-modified-id="odometer-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>odometer</a></span></li><li><span><a href="#color" data-toc-modified-id="color-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>color</a></span></li><li><span><a href="#interior" data-toc-modified-id="interior-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>interior</a></span></li><li><span><a href="#seller" data-toc-modified-id="seller-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>seller</a></span><ul class="toc-item"><li><span><a href="#sold_by_dealer" data-toc-modified-id="sold_by_dealer-3.12.1"><span class="toc-item-num">3.12.1&nbsp;&nbsp;</span>sold_by_dealer</a></span></li><li><span><a href="#sold_by_bank" data-toc-modified-id="sold_by_bank-3.12.2"><span class="toc-item-num">3.12.2&nbsp;&nbsp;</span>sold_by_bank</a></span></li></ul></li><li><span><a href="#saledate" data-toc-modified-id="saledate-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>saledate</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-бренда" data-toc-modified-id="Зависимость-цены-от-бренда-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Зависимость цены от бренда</a></span><ul class="toc-item"><li><span><a href="#Популярность-бренда" data-toc-modified-id="Популярность-бренда-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Популярность бренда</a></span></li><li><span><a href="#Популярность-модели" data-toc-modified-id="Популярность-модели-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Популярность модели</a></span></li><li><span><a href="#Средняя-стоимость-модели" data-toc-modified-id="Средняя-стоимость-модели-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Средняя стоимость модели</a></span></li></ul></li><li><span><a href="#Зависимость-цены-от-кузова" data-toc-modified-id="Зависимость-цены-от-кузова-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Зависимость цены от кузова</a></span></li><li><span><a href="#Зависимость-цены-от-года-выпуска" data-toc-modified-id="Зависимость-цены-от-года-выпуска-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Зависимость цены от года выпуска</a></span></li><li><span><a href="#Зависимость-цены-от-дня-или-месяца-покупки" data-toc-modified-id="Зависимость-цены-от-дня-или-месяца-покупки-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Зависимость цены от дня или месяца покупки</a></span></li><li><span><a href="#Зависимость-цены-от-оснащения" data-toc-modified-id="Зависимость-цены-от-оснащения-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Зависимость цены от оснащения</a></span></li><li><span><a href="#Зависимость-цены-от-кузова" data-toc-modified-id="Зависимость-цены-от-кузова-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Зависимость цены от кузова</a></span></li><li><span><a href="#Зависимость-цены-от-коробки-передач" data-toc-modified-id="Зависимость-цены-от-коробки-передач-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Зависимость цены от коробки передач</a></span></li><li><span><a href="#Зависимость-цены-от-штата" data-toc-modified-id="Зависимость-цены-от-штата-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Зависимость цены от штата</a></span><ul class="toc-item"><li><span><a href="#Налоги-в-штате-на-продажу-автомобилей" data-toc-modified-id="Налоги-в-штате-на-продажу-автомобилей-4.8.1"><span class="toc-item-num">4.8.1&nbsp;&nbsp;</span>Налоги в штате на продажу автомобилей</a></span></li></ul></li><li><span><a href="#Зависимость-цены-от-состояния" data-toc-modified-id="Зависимость-цены-от-состояния-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Зависимость цены от состояния</a></span></li><li><span><a href="#Зависимость-цены-от-пробега" data-toc-modified-id="Зависимость-цены-от-пробега-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Зависимость цены от пробега</a></span></li><li><span><a href="#Зависимость-цены-от-цвета" data-toc-modified-id="Зависимость-цены-от-цвета-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Зависимость цены от цвета</a></span></li><li><span><a href="#Зависимость-цены-от-салона" data-toc-modified-id="Зависимость-цены-от-салона-4.12"><span class="toc-item-num">4.12&nbsp;&nbsp;</span>Зависимость цены от салона</a></span></li><li><span><a href="#Зависимость-цены-от-продавца" data-toc-modified-id="Зависимость-цены-от-продавца-4.13"><span class="toc-item-num">4.13&nbsp;&nbsp;</span>Зависимость цены от продавца</a></span></li><li><span><a href="#Heatmap" data-toc-modified-id="Heatmap-4.14"><span class="toc-item-num">4.14&nbsp;&nbsp;</span>Heatmap</a></span></li></ul></li><li><span><a href="#Создание-дополнительных-признаков" data-toc-modified-id="Создание-дополнительных-признаков-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Создание дополнительных признаков</a></span><ul class="toc-item"><li><span><a href="#Сегмент-авто" data-toc-modified-id="Сегмент-авто-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Сегмент авто</a></span></li><li><span><a href="#Состояние-машины" data-toc-modified-id="Состояние-машины-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Состояние машины</a></span></li><li><span><a href="#Возраст-авто-и-его-группа" data-toc-modified-id="Возраст-авто-и-его-группа-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Возраст авто и его группа</a></span></li><li><span><a href="#Активность-использования" data-toc-modified-id="Активность-использования-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Активность использования</a></span></li><li><span><a href="#Популярность-авто" data-toc-modified-id="Популярность-авто-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Популярность авто</a></span></li></ul></li><li><span><a href="#Подготовка-признакового-пространства" data-toc-modified-id="Подготовка-признакового-пространства-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подготовка признакового пространства</a></span><ul class="toc-item"><li><span><a href="#Создание-и-кодирование-признаков" data-toc-modified-id="Создание-и-кодирование-признаков-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Создание и кодирование признаков</a></span></li><li><span><a href="#Разделение-выборки" data-toc-modified-id="Разделение-выборки-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Разделение выборки</a></span></li><li><span><a href="#Наивная-модель" data-toc-modified-id="Наивная-модель-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Наивная модель</a></span></li><li><span><a href="#HistGradientBoosting" data-toc-modified-id="HistGradientBoosting-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>HistGradientBoosting</a></span><ul class="toc-item"><li><span><a href="#feature-importance" data-toc-modified-id="feature-importance-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>feature importance</a></span></li><li><span><a href="#Подбор-гиперпараметров-для-HistGBR" data-toc-modified-id="Подбор-гиперпараметров-для-HistGBR-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Подбор гиперпараметров для HistGBR</a></span></li></ul></li><li><span><a href="#catboost" data-toc-modified-id="catboost-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>catboost</a></span><ul class="toc-item"><li><span><a href="#Переподготовим-датасет" data-toc-modified-id="Переподготовим-датасет-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Переподготовим датасет</a></span></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-6.5.2"><span class="toc-item-num">6.5.2&nbsp;&nbsp;</span>Обучение модели</a></span></li></ul></li></ul></li><li><span><a href="#Output" data-toc-modified-id="Output-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Output</a></span><ul class="toc-item"><li><span><a href="#HistGradientBoostingRegressor-Output" data-toc-modified-id="HistGradientBoostingRegressor-Output-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>HistGradientBoostingRegressor Output</a></span></li><li><span><a href="#catboost-Output" data-toc-modified-id="catboost-Output-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>catboost Output</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Постановка задачи
#
# Целью вашего проекта будет разработанная модель предсказания стоимости автомобиля на вторичном рынке.

# %% [markdown]
# ## Описание и загрузка данных
#
#
# * Date: Год выпуска автомобиля.
# * Make: Марка автомобиля.
# * Model: издание автомобиля определенной марки.
# * Trim: Уровни отделки салона автомобиля — это просто разные версии модели.
# * Body: Тип кузова транспортного средства относится к форме и модели конкретной марки автомобиля.
# * Transmission: механизм, который передает мощность от двигателя к колесам.
# * VIN: идентификационный номер транспортного средства.
# * State: состояние, в котором автомобиль выставлен на аукцион.
# * Condition: Состояние автомобилей на момент аукциона.
# * Odometer: расстояние, пройденное автомобилем с момента выпуска.
# * Color: Цвет кузова автомобиля.
# * Interior: Цвет салона автомобиля.
# * Seller: Продавец автомобиля, автосалоны.
# * mmr: Рекорд рынка Manhiem, рыночная оценочная цена автомобилей.
# * sellingprice: цена, по которой автомобиль был продан на аукционе.
# * saledate: Дата продажи автомобиля.

# %%
#Импортируем библиотеки
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor

from catboost import CatBoostRegressor, Pool

from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

import numpy as np
from sklearn.inspection import permutation_importance


import re
from collections import Counter
from dateutil import parser

pd.set_option('display.max_rows', None)

# %%
# Загружаем данные
data = pd.read_csv('/Users/inikiforov/Python/practicum/workshop1/train.csv')
test = pd.read_csv('/Users/inikiforov/Python/practicum/workshop1/test.csv')
    
datasets = [data, test]

# %% [markdown]
# ## Предварительная обработка данных

# %%
combined = data.append(test)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/2342155377.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = data.append(test)

# %%
combined.reset_index(drop=True, inplace=True)

# %%
combined.shape
# Out:
# (550294, 15)

# %% [markdown]
# ### make

# %%
combined.groupby('make')['vin'].count().sort_values(ascending = False)
# Out:
# make
# Ford             92091
# Chevrolet        59231
# Nissan           53280
# Toyota           39345
# Dodge            30237
# Honda            26837
# Hyundai          21576
# BMW              20316
# Kia              17889
# Chrysler         17047
# Mercedes-Benz    16808
# Infiniti         15125
# Jeep             15065
# Volkswagen       12368
# Lexus            11675
# GMC              10391
# Mazda             8233
# Cadillac          7346
# Acura             5805
# Audi              5751
# Lincoln           5665
# Buick             5028
# Subaru            4974
# Ram               4481
# Pontiac           4435
# Mitsubishi        4102
# Volvo             3723
# MINI              3147
# Saturn            2791
# Mercury           1964
# Land Rover        1691
# Scion             1656
# Jaguar            1397
# Porsche           1355
# Suzuki            1063
# FIAT               853
# HUMMER             771
# Saab               477
# ford               441
# ...

# %%
combined['make'].unique()
# Out:
# array(['Ford', 'Nissan', 'HUMMER', 'Lincoln', 'pontiac', 'Hyundai', nan,
#        'Buick', 'Chevrolet', 'Honda', 'Acura', 'Cadillac', 'GMC', 'Saab',
#        'Dodge', 'Mercedes-Benz', 'Toyota', 'Volkswagen', 'BMW',
#        'Infiniti', 'Chrysler', 'Kia', 'Jaguar', 'Subaru', 'Jeep', 'Lexus',
#        'mercedes', 'Scion', 'FIAT', 'Suzuki', 'Mazda', 'Volvo', 'Audi',
#        'MINI', 'Isuzu', 'Mitsubishi', 'smart', 'Pontiac', 'Porsche',
#        'subaru', 'ford', 'Land Rover', 'chrysler', 'Saturn', 'mazda',
#        'dodge', 'Ram', 'Oldsmobile', 'hyundai', 'Mercury', 'Bentley',
#        'toyota', 'lincoln', 'Fisker', 'nissan', 'chevrolet', 'honda',
#        'porsche', 'mitsubishi', 'lexus', 'bmw', 'Maserati', 'acura',
#        'jeep', 'mercury', 'Tesla', 'landrover', 'vw', 'cadillac', 'buick',
#        'gmc truck', 'land rover', 'volkswagen', 'Rolls-Royce', 'audi',
#        'Ferrari', 'suzuki', 'Plymouth', 'oldsmobile', 'Lamborghini',
# ...

# %%
combined['make'] = combined['make'].str.lower()

# %%
combined['make'].unique()
# Out:
# array(['ford', 'nissan', 'hummer', 'lincoln', 'pontiac', 'hyundai', nan,
#        'buick', 'chevrolet', 'honda', 'acura', 'cadillac', 'gmc', 'saab',
#        'dodge', 'mercedes-benz', 'toyota', 'volkswagen', 'bmw',
#        'infiniti', 'chrysler', 'kia', 'jaguar', 'subaru', 'jeep', 'lexus',
#        'mercedes', 'scion', 'fiat', 'suzuki', 'mazda', 'volvo', 'audi',
#        'mini', 'isuzu', 'mitsubishi', 'smart', 'porsche', 'land rover',
#        'saturn', 'ram', 'oldsmobile', 'mercury', 'bentley', 'fisker',
#        'maserati', 'tesla', 'landrover', 'vw', 'gmc truck', 'rolls-royce',
#        'ferrari', 'plymouth', 'lamborghini', 'geo', 'ford truck',
#        'aston martin', 'daewoo', 'mercedes-b', 'dodge tk', 'mazda tk',
#        'dot', 'airstream', 'chev truck', 'lotus', 'hyundai tk', 'ford tk'],
#       dtype=object)

# %%
car_brands_dict = {
    'mercedes-b':'mercedes-benz',
    'mercedes': 'mercedes-benz',
    'scion': 'toyota',
    'ram': 'dodge',
    'dodge tk': 'dodge',
    'landrover': 'land rover',
    'gmc truck': 'gmc',
    'geo': 'chevrolet',
    'ford truck': 'ford',
    'mazda tk': 'mazda',
    'dot': 'other',
    'airstream': 'other',
    'chev truck': 'chevrolet',
    'hyundai tk': 'hyundai',
    'ford tk': 'ford'
}

# %%
combined['make'] = combined['make'].map(car_brands_dict).fillna(combined['make'])

# %%
combined['make'].unique()
# Out:
# array(['ford', 'nissan', 'hummer', 'lincoln', 'pontiac', 'hyundai', nan,
#        'buick', 'chevrolet', 'honda', 'acura', 'cadillac', 'gmc', 'saab',
#        'dodge', 'mercedes-benz', 'toyota', 'volkswagen', 'bmw',
#        'infiniti', 'chrysler', 'kia', 'jaguar', 'subaru', 'jeep', 'lexus',
#        'fiat', 'suzuki', 'mazda', 'volvo', 'audi', 'mini', 'isuzu',
#        'mitsubishi', 'smart', 'porsche', 'land rover', 'saturn',
#        'oldsmobile', 'mercury', 'bentley', 'fisker', 'maserati', 'tesla',
#        'vw', 'rolls-royce', 'ferrari', 'plymouth', 'lamborghini',
#        'aston martin', 'daewoo', 'other', 'lotus'], dtype=object)

# %%
all_makes = combined['make'].unique()

# %%
combined.groupby('make')['vin'].count().sort_values(ascending = False)
# Out:
# make
# ford             92536
# chevrolet        59639
# nissan           53351
# toyota           41095
# dodge            34964
# honda            26982
# hyundai          21597
# bmw              20390
# kia              17896
# chrysler         17255
# mercedes-benz    16879
# jeep             15176
# infiniti         15125
# volkswagen       12392
# lexus            11793
# gmc              10427
# mazda             8380
# cadillac          7454
# acura             5830
# audi              5759
# lincoln           5694
# buick             5042
# subaru            5034
# pontiac           4462
# mitsubishi        4219
# volvo             3723
# mini              3147
# saturn            2791
# mercury           1995
# land rover        1847
# jaguar            1397
# porsche           1374
# suzuki            1068
# fiat               853
# hummer             771
# saab               477
# smart              392
# oldsmobile         382
# isuzu              201
# ...

# %% [markdown]
# ### year

# %%
combined['year_date'] = pd.to_datetime(combined['year'], format='%Y')

# %%
sns.histplot(data = combined, x = 'year_date', bins = 30)

plt.show()

# %% [markdown]
# Year is ok.

# %% [markdown]
# ### model

# %%
print(combined['model'].unique()[:10])
print(len(combined['model'].unique()))
# Out:
# ['Edge' 'Fusion' 'Sentra' 'H2' 'MKZ' 'g6' 'Escape' 'Elantra' 'Freestyle'
#  nan]
# 974

# %%
combined['model'] = combined['model'].str.lower()

# %%
print(combined['model'].unique()[:10])
print(len(combined['model'].unique()))
# Out:
# ['edge' 'fusion' 'sentra' 'h2' 'mkz' 'g6' 'escape' 'elantra' 'freestyle'
#  nan]
# 852

# %%
combined.groupby(['make', 'model'])['vin'].count().sort_values(ascending=False).head(50)
# Out:
# make           model
# nissan         altima              19190
# ford           f-150               14145
#                fusion              12797
# toyota         camry               12423
# ford           escape              11743
#                focus               10290
# honda          accord               9050
# bmw            3 series             8068
# dodge          grand caravan        7860
# chevrolet      impala               7846
# ford           explorer             7675
# honda          civic                7363
# infiniti       g sedan              7345
# toyota         corolla              7297
# chevrolet      malibu               7063
# hyundai        sonata               6848
# nissan         maxima               6517
# chevrolet      cruze                6276
# hyundai        elantra              6214
# chevrolet      silverado 1500       6214
# chrysler       town and country     5934
# ford           edge                 5807
# ...

# %%
combined.groupby(['make', 'model'])['vin'].count().head(10)
# Out:
# make   model
# acura  cl           95
#        el            2
#        ilx         137
#        integra      44
#        legend        9
#        mdx        1546
#        rdx         410
#        rl          130
#        rlx          17
#        rsx         149
# Name: vin, dtype: int64

# %% [markdown]
# Нет особого смысла устранять все ошибки в написании отдельных моделей. Но есть несколько популярных автомобилей, таких как nissan altima или ford f-150, что возможно имеет смысл рассмотреть отдельную модель для каждой из них

# %% [markdown]
# ### trim

# %%
print(combined['trim'].unique()[:10])
print(len(combined['trim'].unique()))
# Out:
# ['SEL' 'SE' '2.0 SL' 'Base' '4c' 'GLS' 'Limited' nan 'CXL' 'LS']
# 1976

# %%
combined['trim'] = combined['trim'].str.lower()

# %%
print(combined['trim'].unique()[:10])
print(len(combined['trim'].unique()))
# Out:
# ['sel' 'se' '2.0 sl' 'base' '4c' 'gls' 'limited' nan 'cxl' 'ls']
# 1902

# %%
combined.groupby(['make', 'trim'])['vin'].count()
# Out:
# make           trim
# acura          2.2                                                   2
#                2.2 premium                                           7
#                2.3                                                   4
#                2.3 premium                                           1
#                2.5                                                   3
#                2.5 premium                                           7
#                3.0                                                  10
#                3.0 premium                                          13
#                3.2                                                 635
#                3.2 premium                                           1
#                3.2 type-s                                          104
#                3.5                                                  61
#                3.5 premium                                           7
# ...

# %% [markdown]
# Интересный признак. Из него можно попробовать вытащить:
#
# * premium/luxury/leather более люксовые комплектации
# * объем двигателя
# * полноприводность (4x4, 4matic, awd, quattro и т.п.)
# * v6/v8 etc

# %% [markdown]
# #### trim features keywords

# %%
def count_frequency(strings):
    counts = Counter(strings)
    frequency = sorted(counts.items(), key=lambda x: x[1], reverse=True)
    return frequency

# %%
all_words = []
for i in combined['trim']:
    words = str(i).lower()
    words = words.split()
    for y in words:
        all_words.append(y)
        
freq = count_frequency(all_words)

for string, count in freq:
    print(string, count)
# Out:
# base 55159
# se 47840
# s 29943
# lx 21209
# limited 20244
# lt 19915
# 2.5 18700
# xlt 18442
# ls 17668
# sport 17324
# le 14587
# touring 13813
# gls 12952
# sxt 11715
# sv 11105
# sel 10861
# ex 10487
# nan 10451
# premium 8966
# 3.5 7485
# pzev 7274
# fleet 7220
# ltz 6343
# slt 6307
# ex-l 6252
# v6 6097
# sl 5518
# 4matic 5483
# xl 4767
# 328i 4646
# quattro 4476
# luxury 4269
# g37x 4133
# g37 4096
# i 3893
# 1500 3738
# 2.0t 3351
# lariat 3337
# journey 3027
# titanium 3024
# xdrive 3003
# 1lt 2947
# e350 2890
# sle 2886
# 2.0 2774
# laredo 2715
# 2.5i 2700
# gt 2697
# xle 2618
# unlimited 2372
# 1.6 2359
# edition 2267
# c300 2229
# 2lt 2113
# 7-passenger 2059
# work 2012
# truck 2009
# r/t 2001
# 1.8 1966
# 3.2 1898
# plus 1897
# c250 1866
# e-250 1831
# denali 1810
# sr 1740
# package 1726
# fx4 1664
# es 1646
# lt1 1641
# xls 1634
# v-6 1619
# + 1612
# super 1602
# e-350 1586
# duty 1586
# l 1532
# sr5 1524
# 2500 1486
# ml350 1461
# 528i 1431
# st 1323
# 535i 1313
# ...

# %% [markdown]
# #### 4x4

# %%
def is_4x4(row):
    trim = str(row['trim'])
    make = row['make']
    pattern = re.compile(r'awd|4x4|quattro|4-matic|xdrive|xdr|xi|4motion|wrx|4s|4matic')
    if re.search(pattern, trim):
        return 'awd'
    elif make in ['subaru', 'jeep','land rover']:
        return 'awd'
    else:
        return 'unknown'

# %%
combined['awd'] = combined.apply(is_4x4, axis = 1)

# %%
combined.groupby('awd')['vin'].count()
# Out:
# awd
# awd         39774
# unknown    510520
# Name: vin, dtype: int64

# %% [markdown]
# #### special

# %%
def is_special(row):
    trim = str(row['trim'])
    pattern = re.compile(r'luxury|premium|leather|special|premier|executive|edition|design|amg|elite|limited|sti|brabus|package|packages|sport')
    base_pattern = re.compile(r'base|standard')
    if re.search(pattern, trim):
        return 'special'
    elif re.search(base_pattern, trim):
        return 'base'
    else:
        return 'unknown'

# %%
combined['special'] = combined.apply(is_special, axis = 1)

# %%
combined.groupby('special')['vin'].count()
# Out:
# special
# base        55417
# special     58908
# unknown    435969
# Name: vin, dtype: int64

# %% [markdown]
# #### engine

# %%
def what_engine(row):
    trim = str(row['trim'])
    v6 = re.compile(r'v6|v-6')
    v8 = re.compile(r'v8|v-8')
    
    if re.search(v6, trim):
        return 'v6'
    elif re.search(v8, trim):
        return 'v8'
    else:
        return 'unknown'

# %%
combined['engine'] = combined.apply(what_engine, axis = 1)

# %%
combined.groupby('engine')['vin'].count()
# Out:
# engine
# unknown    541609
# v6           8039
# v8            646
# Name: vin, dtype: int64

# %% [markdown]
# #### volume

# %%
def volume(trim):
    pattern = r'\d+\.\d+?'
    matches = re.findall(pattern, trim)
    
    if matches:
        try:
            return float(matches[0])
        except ValueError:
            return None
    
    return None

# %%
volume('3.2 premium ')
# Out:
# 3.2

# %%
def get_volume(row):
    trim = str(row['trim'])
    result = volume(trim)
    try:
        if result <10:
            return result
        else:
            return None
    except:
        return None

# %%
combined['volume'] = combined.apply(get_volume, axis = 1)

# %%
combined.groupby('volume')['vin'].count()
# Out:
# volume
# 1.0        6
# 1.6     2359
# 1.8     2879
# 1.9       14
# 2.0     6558
# 2.2        9
# 2.3       54
# 2.4      469
# 2.5    22926
# 2.7       62
# 2.8       83
# 2.9       74
# 3.0     2184
# 3.2     1902
# 3.5     7499
# 3.6      334
# 3.8      811
# 4.0       73
# 4.2      323
# 4.4      234
# 4.6      150
# 4.8      204
# 5.0       75
# 5.2       16
# 5.3       20
# 6.3        1
# Name: vin, dtype: int64

# %%
combined.head(40)
# Out:
#     year           make           model          trim          body  \
# 0   2011           ford            edge           sel           suv
# 1   2014           ford          fusion            se         Sedan
# 2   2012         nissan          sentra        2.0 sl         sedan
# 3   2003         hummer              h2          base           suv
# 4   2007           ford          fusion           sel         Sedan
# 5   2013        lincoln             mkz          base         Sedan
# 6   2010        pontiac              g6            4c           NaN
# 7   2013           ford          escape            se           SUV
# 8   2000        hyundai         elantra           gls         Sedan
# 9   2005           ford       freestyle       limited         wagon
# 10  2007            NaN             NaN           NaN           NaN
# 11  2011          buick         lucerne           cxl         Sedan
# 12  2003           ford        windstar          base       Minivan
# ...

# %% [markdown]
# ### body

# %%
print(combined['body'].unique()[:10])
print(len(combined['body'].unique()))
# Out:
# ['suv' 'Sedan' 'sedan' nan 'SUV' 'wagon' 'Minivan' 'Extended Cab'
#  'Regular Cab' 'Coupe']
# 86

# %%
combined['body'] = combined['body'].str.lower()

# %%
combined['body'].unique()
# Out:
# array(['suv', 'sedan', nan, 'wagon', 'minivan', 'extended cab',
#        'regular cab', 'coupe', 'supercrew', 'convertible', 'crew cab',
#        'supercab', 'hatchback', 'g coupe', 'g convertible', 'access cab',
#        'g sedan', 'e-series van', 'quad cab', 'tsx sport wagon', 'van',
#        'cts coupe', 'koup', 'king cab', 'double cab', 'elantra coupe',
#        'crewmax cab', 'genesis coupe', 'g37 coupe', 'club cab',
#        'beetle convertible', 'mega cab', 'regular-cab', 'xtracab',
#        'q60 coupe', 'promaster cargo van', 'cts-v coupe', 'cts wagon',
#        'cab plus 4', 'g37 convertible', 'transit van', 'q60 convertible',
#        'cab plus', 'ram van', 'granturismo convertible', 'cts-v wagon'],
#       dtype=object)

# %%
combined.groupby('body')['vin'].count().sort_values()
# Out:
# body
# cts-v wagon                     1
# ram van                         1
# cab plus                        4
# cab plus 4                      6
# g37 coupe                      12
# granturismo convertible        13
# cts wagon                      13
# regular-cab                    15
# transit van                    19
# g37 convertible                20
# cts-v coupe                    35
# tsx sport wagon                36
# q60 coupe                      36
# q60 convertible                42
# xtracab                        43
# promaster cargo van            59
# beetle convertible             59
# elantra coupe                 103
# mega cab                      111
# cts coupe                     153
# club cab                      176
# koup                          178
# access cab                    286
# genesis coupe                 289
# g convertible                 320
# king cab                      513
# crewmax cab                   546
# ...

# %%
def is_pickup(row):
    body = str(row['body'])
    pattern = re.compile(r'cab|crew')
    if re.search(pattern, body):
        return 'pickup'
    else:
        return body

# %%
def is_coupe(row):
    body = str(row['body'])
    pattern = re.compile(r'coupe|koup')
    if re.search(pattern, body):
        return 'coupe'
    else:
        return body

# %%
def is_van(row):
    body = str(row['body'])
    pattern = re.compile(r'van')
    if re.search(pattern, body):
        return 'van'
    else:
        return body

# %%
def split_return(row):
    s = str(row['body'])
    return s.split()[-1]

# %%
combined['body'] = combined.apply(is_pickup, axis = 1)

# %%
combined['body'] = combined.apply(is_coupe, axis = 1)

# %%
combined['body'] = combined.apply(is_van, axis = 1)

# %%
combined['body'] = combined.apply(split_return, axis = 1)

# %%
combined['body'] = combined['body'].fillna('unknown')

# %%
combined.groupby('body')['vin'].count().sort_values()
# Out:
# body
# convertible     10696
# nan             12987
# wagon           15926
# coupe           19786
# hatchback       25867
# van             31560
# pickup          46445
# suv            141337
# sedan          245690
# Name: vin, dtype: int64

# %% [markdown]
# ### transmission

# %%
combined['transmission'].unique()
# Out:
# array(['automatic', nan, 'manual'], dtype=object)

# %%
combined.groupby('transmission')['vin'].count()
# Out:
# transmission
# automatic    468645
# manual        17177
# Name: vin, dtype: int64

# %%
combined['transmission'] = combined['transmission'].fillna('automatic')

# %%
combined.groupby('transmission')['vin'].count()
# Out:
# transmission
# automatic    533117
# manual        17177
# Name: vin, dtype: int64

# %% [markdown]
# ### state

# %%
combined['state'].unique()
# Out:
# array(['md', 'mo', 'nj', 'tx', 'mi', 'nc', 'fl', 'oh', 'ca', 'az', 'ga',
#        'tn', 'in', 'pa', 'va', 'wi', 'co', 'ny', 'il', 'nv', 'mn', 'wa',
#        'sc', 'la', 'ne', 'ok', 'or', 'on', 'ma', 'ab', 'pr', 'hi', 'ut',
#        'qc', 'ms', 'nm', 'ns', 'al'], dtype=object)

# %%
combined['state'] = combined['state'].fillna('unknown')

# %%
combined['state'].unique()
# Out:
# array(['md', 'mo', 'nj', 'tx', 'mi', 'nc', 'fl', 'oh', 'ca', 'az', 'ga',
#        'tn', 'in', 'pa', 'va', 'wi', 'co', 'ny', 'il', 'nv', 'mn', 'wa',
#        'sc', 'la', 'ne', 'ok', 'or', 'on', 'ma', 'ab', 'pr', 'hi', 'ut',
#        'qc', 'ms', 'nm', 'ns', 'al'], dtype=object)

# %% [markdown]
# ### condition

# %%
combined['condition'].unique()
# Out:
# array([4.2, 3.5, 2.2, 2.8, 2. , 2.5, 3.4, 4.8, 1.9, 1. , 3.1, 2.7, 3.6,
#        2.9, 4.1, 2.6, 2.1, 3. , 4.9, 4.7, 4. , 3.3, 3.8, 3.7, 4.5, 4.6,
#        5. , 4.3, 2.4, 2.3, 3.9, nan, 3.2, 4.4, 1.4, 1.5, 1.7, 1.2, 1.3,
#        1.6, 1.8, 1.1])

# %%
#combined['condition'] = combined['condition'].fillna(combined['condition'].median())

# %%
combined['condition'] = combined['condition'].fillna(0)

# %%
combined.groupby('condition')['vin'].count()
# Out:
# condition
# 0.0    11784
# 1.0     7323
# 1.1       87
# 1.2       95
# 1.3       81
# 1.4      132
# 1.5      143
# 1.6      175
# 1.7      240
# 1.8      318
# 1.9    41636
# 2.0    20548
# 2.1     9042
# 2.2     5941
# 2.3     8039
# 2.4     9158
# 2.5    12344
# 2.6    11693
# 2.7    16072
# 2.8    18876
# 2.9    18633
# 3.0    10645
# 3.1     9049
# 3.2     9780
# 3.3    10435
# 3.4    17076
# 3.5    26249
# 3.6    22783
# 3.7    25465
# 3.8    18454
# 3.9    19618
# 4.0    19718
# 4.1    22660
# 4.2    23976
# 4.3    24544
# 4.4    25123
# 4.5    12123
# 4.6    12454
# 4.7    11210
# 4.8    12561
# 4.9    12931
# 5.0    11080
# Name: vin, dtype: int64

# %% [markdown]
# ### odometer

# %%
sns.histplot(data = combined, x = 'odometer', bins = 30)

plt.show()

# %%
combined['odometer'] = combined['odometer'].fillna(combined['odometer'].median())

# %% [markdown]
# ### color

# %%
combined['color'].unique()
# Out:
# array(['black', 'gold', 'silver', 'blue', 'white', 'gray', '—', 'red',
#        'brown', 'green', 'beige', 'orange', nan, 'off-white', 'burgundy',
#        'yellow', 'charcoal', 'purple', 'turquoise', 'lime', 'pink'],
#       dtype=object)

# %%
combined['color'] = combined['color'].replace('—','unknown')
combined['color'] = combined['color'].fillna('unknown')

# %%
sns.countplot(data = combined, y = 'color')

plt.show()

# %% [markdown]
# ### interior

# %%
combined['interior'].unique()
# Out:
# array(['black', 'beige', 'gray', 'tan', 'brown', '—', 'off-white', nan,
#        'blue', 'white', 'silver', 'red', 'green', 'gold', 'purple',
#        'orange', 'burgundy', 'yellow'], dtype=object)

# %%
combined['interior'] = combined['interior'].replace('—','unknown')
combined['interior'] = combined['interior'].fillna('unknown')

# %%
sns.countplot(data = combined, y = 'interior')

plt.show()

# %%
def simplify_interior(row):
    i = row['interior']
    if i in ['black', 'beige','gray','tan','brown']:
        return i
    else:
        return 'other'

# %%
combined['interior'] = combined.apply(simplify_interior, axis = 1)

# %%
sns.countplot(data = combined, y = 'interior')

plt.show()

# %% [markdown]
# ### seller

# %%
#for i in combined['seller'].unique():
    #print(i)

# %% [markdown]
# Еще один интересный признак. Можно попробовать отсюда вытащить информацию о том специализированный ли дилер продал машину

# %% [markdown]
# #### sold_by_dealer

# %%
def sold_by_dealer(row):
    make = row['make']
    seller = str(row['seller']).lower()
    seller = seller.split()
    if make in seller:
        return 'dealer'
    else:
        return 'unknown'

# %%
combined['sold_by_dealer'] = combined.apply(sold_by_dealer, axis = 1)

# %%
combined.groupby('sold_by_dealer')['vin'].count()
# Out:
# sold_by_dealer
# dealer     102471
# unknown    447823
# Name: vin, dtype: int64

# %% [markdown]
# #### sold_by_bank

# %% [markdown]
# Заметил, что есть еще что-то похожее на кредитные организации.

# %% [markdown]
# Можно попробовать собрать все слова, которые повторяются в этом поле, выбрать наиболее популярные.

# %%
all_words = []
for i in combined['seller']:
    words = str(i).lower()
    words = i.split()
    for y in words:
        all_words.append(y)

# %%
freq = count_frequency(all_words)

for string, count in freq:
    print(string, count)
# Out:
# inc 69578
# services 48053
# corporation 47755
# credit 46137
# auto 45823
# motor 45526
# financial 43925
# ford 35938
# remarketing 33350
# lt 29848
# of 29178
# company,llc 23398
# hertz 22655
# nissan 20947
# the 20494
# llc 20125
# finance 19679
# nissan-infiniti 19675
# sales 19161
# avis 18257
# consumer 15875
# toyota 15867
# motors 15827
# santander 15276
# lease 15011
# dealer 14800
# enterprise 14736
# inc. 14715
# acceptance 14222
# group 14131
# chrysler 13114
# / 12138
# hyundai 11856
# capital 11833
# infiniti 11695
# fleet 11263
# gm 11229
# exchange 10557
# ahfc/honda 9863
# car 9815
# kia 9199
# wells 9140
# fargo 9131
# honda 8960
# trust/hvt, 8758
# budget 8724
# chevrolet 8270
# america 8041
# lexus 7929
# bmw 7854
# by 7375
# company 7310
# mercedes-benz 7278
# eot 7169
# usa 7101
# & 7079
# veh 6851
# exchange/rental 6851
# ge 6834
# for 6784
# jeep 6726
# tdaf 6712
# itself/servicer 6671
# dt 6547
# north 6540
# leasing 6492
# bank 6451
# dodge 6449
# ...

# %%
def sold_by_bank(row):
    pattern = re.compile(r'financing|credit|lenders|union|financial|leasing|finance|bank|brokers|capital|lease|santander|fargo|jpmorgan')
    if re.search(pattern, row['seller']):
        return 'bank'
    else:
        return 'unknown'

# %%
combined['sold_by_bank'] = combined.apply(sold_by_bank, axis = 1)

# %%
combined.groupby('sold_by_bank')['vin'].count()
# Out:
# sold_by_bank
# bank       181854
# unknown    368440
# Name: vin, dtype: int64

# %% [markdown]
# Не уверен насчет включения leasing, но пока оставим так. Еще как вариант скомбинировать leasing и rentals/avis/budget/enterprise и т.п. то есть прокатные машины.

# %% [markdown]
# ### saledate

# %%
combined['saledate'].head()
# Out:
# 0    Tue Jun 02 2015 02:30:00 GMT-0700 (PDT)
# 1    Wed Feb 25 2015 02:00:00 GMT-0800 (PST)
# 2    Wed Jun 10 2015 02:30:00 GMT-0700 (PDT)
# 3    Wed Jun 17 2015 03:00:00 GMT-0700 (PDT)
# 4    Tue Feb 03 2015 04:00:00 GMT-0800 (PST)
# Name: saledate, dtype: object

# %%
def convert_to_datetime(date_string):
    split_date = date_string.split(' ')
    date_only = ' '.join(split_date[:4])
    return pd.to_datetime(date_only, format='%a %b %d %Y')

# %%
combined['saledate_converted'] = combined['saledate'].apply(convert_to_datetime)

# %% [markdown]
# ## Исследовательский анализ данных

# %%
research = combined.query('sellingprice.notnull()')

# %%
research.shape
# Out:
# (440236, 23)

# %% [markdown]
# ### Зависимость цены от бренда

# %%
research.groupby('make')['sellingprice'].median().sort_values().tail(40).plot(kind = 'barh')

plt.show()

# %%
brand_median = research.groupby('make')['sellingprice'].median().sort_values()

# %%
brand_median
# Out:
# make
# daewoo              600.0
# oldsmobile          700.0
# plymouth            700.0
# isuzu              1200.0
# saturn             2700.0
# saab               3000.0
# mercury            3100.0
# suzuki             3200.0
# pontiac            3200.0
# smart              5750.0
# mitsubishi         7500.0
# volvo              8500.0
# mazda              9700.0
# vw                 9800.0
# volkswagen         9800.0
# fiat              10100.0
# chrysler          10300.0
# chevrolet         10400.0
# buick             10500.0
# honda             11000.0
# hyundai           11400.0
# dodge             11500.0
# nissan            12000.0
# toyota            12000.0
# kia               12200.0
# mini              12500.0
# ford              13400.0
# hummer            13500.0
# jeep              13800.0
# cadillac          14200.0
# acura             14500.0
# jaguar            16000.0
# gmc               16500.0
# subaru            16500.0
# lincoln           17200.0
# ...

# %%
luxury = ['rolls-royce', 'ferrari', 'lamborghini']
premium = ['tesla', 'bentley', 'aston_martin', 'fisker', 'maserati', 'porsche', 'other', 'landrover']
sub_premium = ['mercedes-benz', 'infinity', 'lesux', 'bmw', 'audi']

# %% [markdown]
# Стоимость автомобиля зависит от бренда

# %% [markdown]
# #### Популярность бренда

# %%
brand_popularity = research.groupby('make')['sellingprice'].count().sort_values(ascending = False)

# %%
brand_popularity
# Out:
# make
# ford             74070
# chevrolet        47834
# nissan           42866
# toyota           33049
# dodge            27887
# honda            21600
# hyundai          17187
# bmw              16254
# kia              14325
# chrysler         13796
# mercedes-benz    13408
# infiniti         12123
# jeep             12107
# volkswagen        9883
# lexus             9363
# gmc               8368
# mazda             6704
# cadillac          5958
# acura             4679
# audi              4635
# lincoln           4541
# buick             4023
# subaru            4019
# pontiac           3596
# mitsubishi        3413
# volvo             2958
# mini              2473
# saturn            2247
# mercury           1561
# land rover        1476
# jaguar            1100
# porsche           1094
# suzuki             846
# fiat               672
# hummer             597
# saab               384
# smart              311
# oldsmobile         294
# isuzu              163
# ...

# %%
def brand_popularity_groups(row):
    make = row['make']
    try:
        sellers = brand_popularity[make]
    except:
        return 'unknown'
    if sellers > 30000:
        return 'group_1'
    elif sellers <= 30000 and sellers >20000:
        return 'group_2'
    elif sellers <=20000 and sellers >10000:
        return 'group_3'
    elif sellers <=10000 and sellers >5000:
        return 'group_4'
    elif sellers <=5000 and sellers >1000:
        return 'group_5'
    else:
        return 'group_6'

# %% [markdown]
# #### Популярность модели

# %%
combined.groupby(['make', 'model'])['vin'].count().sort_values(ascending=False).head(10)
# Out:
# make       model
# nissan     altima           19190
# ford       f-150            14145
#            fusion           12797
# toyota     camry            12423
# ford       escape           11743
#            focus            10290
# honda      accord            9050
# bmw        3 series          8068
# dodge      grand caravan     7860
# chevrolet  impala            7846
# Name: vin, dtype: int64

# %%
model_popularity = research.groupby(['make', 'model'])['sellingprice'].count().sort_values(ascending=False)

# %%
model_popularity.head(10)
# Out:
# make       model
# nissan     altima           15454
# ford       f-150            11408
#            fusion           10244
# toyota     camry            10000
# ford       escape            9447
#            focus             8222
# honda      accord            7226
# bmw        3 series          6406
# chevrolet  impala            6305
# dodge      grand caravan     6258
# Name: sellingprice, dtype: int64

# %%
model_popularity['nissan']['altima']
# Out:
# 15454

# %%
def model_popularity_groups(row):
    make = row['make']
    model = row['model']
    try:
        sellers = model_popularity[make][model]
    except:
        return 'unknown'
    if sellers > 10000:
        return 'group_1'
    elif sellers <= 10000 and sellers >6000:
        return 'group_2'
    elif sellers <=6000 and sellers >4000:
        return 'group_3'
    elif sellers <=4000 and sellers >2000:
        return 'group_4'
    elif sellers <=2000 and sellers >1000:
        return 'group_5'
    else:
        return 'group_6'

# %% [markdown]
# #### Средняя стоимость модели

# %%
average_model_price = research.groupby(['make', 'model'])['sellingprice'].median()

# %%
average_model_price['ford']['f250']
# Out:
# 6450.0

# %%
def average_price(row):
    make = row['make']
    model = row['model']
    
    try: 
        return average_model_price[make][model]
    except:
        return 5900

# %%
research.query('model.isnull() or make.isnull()')['sellingprice'].median()
# Out:
# 5900.0

# %%
research['average_model_price'] = research.apply(average_price, axis = 1)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/1269281218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['average_model_price'] = research.apply(average_price, axis = 1)

# %% [markdown]
# ### Зависимость цены от кузова

# %%
research.groupby('body')['sellingprice'].median().sort_values().plot(kind = 'barh')

plt.show()

# %% [markdown]
# Также стоимость зависит от кузова. Пикапы и внедорожниики стоят дороже.

# %% [markdown]
# ### Зависимость цены от года выпуска

# %%
grouped = research.groupby('year_date')['sellingprice']
mean = grouped.mean()
median = grouped.median()

mean.plot(label='Mean')
median.plot(label='Median')

plt.legend()
plt.show()

# %% [markdown]
# ### Зависимость цены от дня или месяца покупки

# %%
sns.histplot(data = combined, y = 'saledate_converted', bins = 30)

plt.show()

# %%
research.groupby('saledate_converted')['vin'].count().sort_values()
# Out:
# saledate_converted
# 2015-07-21        1
# 2015-02-15        1
# 2014-01-14        1
# 2014-01-15        1
# 2014-01-29        1
# 2015-06-14        1
# 2015-06-13        1
# 2015-05-24        2
# 2015-06-22        2
# 2014-01-05        3
# 2015-03-16        3
# 2015-04-06        3
# 2014-01-13        3
# 2015-05-31        3
# 2015-03-08        4
# 2015-03-30        4
# 2015-02-07        4
# 2015-05-04        5
# 2015-03-23        6
# 2015-01-04        6
# 2015-04-20        6
# 2015-04-13        6
# 2015-07-10        7
# 2015-01-01        7
# 2015-07-14        9
# 2015-06-29       10
# 2015-04-27       10
# 2015-06-07       11
# 2014-01-02       12
# 2015-06-26       14
# 2014-01-08       14
# 2015-03-13       16
# 2015-04-03       17
# 2015-07-06       18
# 2014-01-12       18
# 2015-05-11       18
# 2015-04-10       19
# 2015-03-27       21
# 2015-03-20       21
# 2015-03-19       23
# 2015-04-17       24
# 2015-04-02       34
# 2015-04-24       34
# 2015-05-18       34
# ...

# %%
research['sale_day'] = research['saledate_converted'].dt.dayofweek
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/3513223875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['sale_day'] = research['saledate_converted'].dt.dayofweek

# %%
sns.histplot(data = research, y = 'sale_day', bins = 30)

plt.show()

# %%
research.groupby('sale_day')['vin'].count()
# Out:
# sale_day
# 0     12512
# 1    129240
# 2    130655
# 3    121366
# 4     46335
# 5         5
# 6       123
# Name: vin, dtype: int64

# %%
research.groupby('sale_day')['sellingprice'].agg(['mean','median', 'count'])
# Out:
#                   mean   median   count
# sale_day
# 0         10675.234095   9000.0   12512
# 1         12834.341133  11500.0  129240
# 2         13694.879806  12200.0  130655
# 3         13868.853287  12100.0  121366
# 4         15475.099665  13800.0   46335
# 5          6928.200000   7940.0       5
# 6         15577.642276  17500.0     123

# %% [markdown]
# Это странно и не очень понятно, что именно с этим делать. Если это не дата продажи, а дата регистрации и регистрация делается в каком-то государственном учереждении типа DMV, то это говорит о том, что это либо выбросы, либо еще что-то.

# %% [markdown]
# Из зависимостей видно, что ближе к выходным покупают более дорогие автомобили.

# %%
days_map = {
    0 : 'mon',
    1 : 'tue',
    2 : 'wed',
    3 : 'th',
    4 : 'fr',
    5 : 'sat',
    6 : 'sun'
}

month_map = {
    1 : 'jan',
    2 : 'feb',
    3 : 'mar',
    4 : 'apr',
    5 : 'may',
    6 : 'jun',
    7 : 'jul',
    8 : 'aug',
    9 : 'sep',
    10 : 'oct',
    11 : 'nov',
    12 : 'dec'
}

# %%
research['sale_day'] = research['sale_day'].map(days_map)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/3350646985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['sale_day'] = research['sale_day'].map(days_map)

# %%
research['sale_month'] = research['saledate_converted'].dt.month
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/827559094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['sale_month'] = research['saledate_converted'].dt.month

# %%
sns.histplot(data = research, y = 'sale_month')

plt.show()

# %%
research.groupby('sale_month')['sellingprice'].agg(['mean','median', 'count'])
# Out:
#                     mean   median   count
# sale_month
# 1           13279.842866  12000.0  111510
# 2           13625.503411  12250.0  127375
# 3           13431.864040  12300.0   35790
# 4           10390.326087   8700.0    1150
# 5           14261.598529  12600.0   41592
# 6           14952.578470  13000.0   79043
# 7           17026.602151  15000.0    1023
# 12          11279.620986   9600.0   42753

# %% [markdown]
# К сожалению представлены далеко не все месяца и не достаточно равномерно, поэтому тяжело будет делать вывод о устойчивости того или иного тренда

# %%
research['sale_month'] = research['sale_month'].map(month_map)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/1847385413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['sale_month'] = research['sale_month'].map(month_map)

# %% [markdown]
# ### Зависимость цены от оснащения

# %%
research.groupby('awd')['sellingprice'].agg(['mean','median', 'count'])
# Out:
#                  mean   median   count
# awd
# awd      19910.747864  18600.0   31721
# unknown  13101.578025  11900.0  408515

# %% [markdown]
# Полноприводные автомобили существенно дороже обычных

# %%
research.groupby('special')['sellingprice'].agg(['mean','median', 'count'])
# Out:
#                  mean   median   count
# special
# base     13771.925138  11500.0   44295
# special  17561.066570  16800.0   47078
# unknown  13033.806004  11800.0  348863

# %% [markdown]
# Аналогичная ситуация с лимитированными и особенными автомобилями

# %%
research.groupby(['special', 'awd'])['sellingprice'].agg(['mean','median', 'count'])
# Out:
#                          mean   median   count
# special awd
# base    awd      13058.231132   7200.0     424
#         unknown  13778.822776  11600.0   43871
# special awd      18879.688211  18200.0   15565
#         unknown  16909.768826  16000.0   31513
# unknown awd      21115.547674  19500.0   15732
#         unknown  12652.148458  11700.0  333131

# %% [markdown]
# Также между обоими этими признакми есть взаимосвязь - полноприводный особенный автомобиль будет дороже, чем с приводом на 2 колеса и без особых признаков

# %% [markdown]
# ### Зависимость цены от кузова

# %%
research.groupby('body')['sellingprice'].agg(['mean','median', 'count'])
# Out:
#                      mean   median   count
# body
# convertible  18317.701533  14500.0    8547
# coupe        16380.584384  14750.0   15791
# hatchback    10064.012213  10000.0   20715
# nan           8555.425382   5500.0   10393
# pickup       17704.089628  17400.0   37243
# sedan        11960.030465  11200.0  196720
# suv          16101.931946  15100.0  113042
# van          12356.925555  12500.0   25146
# wagon        10135.911385   8800.0   12639

# %% [markdown]
# Зависимость однозначно есть - купе и кабриолеты стоят дороже, пикапы самые дорогие

# %% [markdown]
# ### Зависимость цены от коробки передач

# %%
research.groupby('transmission')['sellingprice'].agg(['mean','median', 'count'])
# Out:
#                       mean   median   count
# transmission
# automatic     13672.010846  12200.0  426522
# manual        11110.293860   8500.0   13714

# %% [markdown]
# Здесь есть небольшая проблема. Если мы не знаем, какая коробка передач, то алгоритм может показывать большую стоимость

# %%
#for i in combined.query('transmission == "unknown"')['trim'].unique():
    #print(i)

# %% [markdown]
# Судя по тому, что цена подгруппы 'unknown' выше чем среднее, и учитывая, что manual обычно существенно дешевле автомата, я думаю не будет большой ошибкой, при обработке автоматически присваивать 'automatic' всем, кто не указал коробку.

# %%
def transmission_guesser(row):
    awd = row['awd']
    spe = row['special']
    if row['transmission'] == 'unknown':
        if awd == 1 or spe == 1:
            return 'automatic'
        else:
            return 'still_unknown'
    else:
        return row['transmission']

# %%
combined['transmission'] = combined.apply(transmission_guesser, axis = 1)

# %%
combined.groupby('transmission')['sellingprice'].agg(['mean','median', 'count'])
# Out:
#                       mean   median   count
# transmission
# automatic     13672.010846  12200.0  426522
# manual        11110.293860   8500.0   13714

# %% [markdown]
# По итогу думаю можно спокойно всем неизвестным ставить автоматическую коробку. Отредактирую код выше.

# %% [markdown]
# ### Зависимость цены от штата

# %%
research.groupby('state')['sellingprice'].median().sort_values().plot(kind = 'barh')

plt.show()

# %%
research.groupby(['state'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                mean   median  count
# state
# on     17958.651727  18600.0   2722
# tn     16975.481679  15900.0  16156
# pa     15942.628868  14200.0  42462
# co     15792.232429  14500.0   6118
# nv     15004.957172  13400.0   9830
# mi     14864.950052  13800.0  12393
# il     14772.454131  13900.0  18651
# ca     14543.383612  12250.0  57407
# mo     14462.472499  13300.0  12563
# oh     14421.217996  12500.0  16959
# wa     13956.525752  13200.0   5883
# wi     13872.295449  12300.0   7866
# fl     13836.098647  12500.0  65618
# nj     13629.736268  12200.0  22102
# mn     13607.459387  12500.0   7436
# tx     13159.645441  11600.0  36104
# qc     13028.250000  11000.0   1000
# ga     12949.075310  11400.0  27141
# ne     12674.765640  11600.0   3213
# hi     12176.058468  11750.0    992
# ut     12156.419711  10100.0   1451
# az     11574.705925  10400.0   6903
# or     11500.215517  10900.0    928
# ny     11322.425546   9900.0   4533
# ab     11267.832647   7800.0    729
# ...

# %% [markdown]
# Какая-то зависимость от штата, конечно есть.

# %% [markdown]
# Но я не понимаю, какие штаты указаны, например я не знаю штата с кодом on.

# %%
usa_states = [
    'al', 'ak', 'az', 'ar', 'ca', 'co', 'ct', 'de', 'fl', 'ga',
    'hi', 'id', 'il', 'in', 'ia', 'ks', 'ky', 'la', 'me', 'md',
    'ma', 'mi', 'mn', 'ms', 'mo', 'mt', 'ne', 'nv', 'nh', 'nj',
    'nm', 'ny', 'nc', 'nd', 'oh', 'ok', 'or', 'pa', 'ri', 'sc',
    'sd', 'tn', 'tx', 'ut', 'vt', 'va', 'wa', 'wv', 'wi', 'wy'
]

# %%
data_states = research['state'].unique()

# %%
sus_states = []
for i in data_states:
    if i not in usa_states:
        sus_states.append(i)
        print('This state code is sus:', i)
# Out:
# This state code is sus: on
# This state code is sus: ab
# This state code is sus: pr
# This state code is sus: qc
# This state code is sus: ns

# %%
def state_cleaner(row):
    
    usa_states = [
    'al', 'ak', 'az', 'ar', 'ca', 'co', 'ct', 'de', 'fl', 'ga',
    'hi', 'id', 'il', 'in', 'ia', 'ks', 'ky', 'la', 'me', 'md',
    'ma', 'mi', 'mn', 'ms', 'mo', 'mt', 'ne', 'nv', 'nh', 'nj',
    'nm', 'ny', 'nc', 'nd', 'oh', 'ok', 'or', 'pa', 'ri', 'sc',
    'sd', 'tn', 'tx', 'ut', 'vt', 'va', 'wa', 'wv', 'wi', 'wy'
]
    
    state = row['state']
    if state not in usa_states:
        return 'unknown'
    else:
        return state

# %%
research['state'] = research.apply(state_cleaner, axis = 1)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/681210240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['state'] = research.apply(state_cleaner, axis = 1)

# %%
research.groupby('state')['sellingprice'].median().sort_values().plot(kind = 'barh')

plt.show()

# %%
research.groupby(['state'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                  mean   median  count
# state
# tn       16975.481679  15900.0  16156
# pa       15942.628868  14200.0  42462
# co       15792.232429  14500.0   6118
# nv       15004.957172  13400.0   9830
# mi       14864.950052  13800.0  12393
# il       14772.454131  13900.0  18651
# ca       14543.383612  12250.0  57407
# mo       14462.472499  13300.0  12563
# oh       14421.217996  12500.0  16959
# wa       13956.525752  13200.0   5883
# wi       13872.295449  12300.0   7866
# fl       13836.098647  12500.0  65618
# unknown  13643.135784  11800.0   6665
# nj       13629.736268  12200.0  22102
# mn       13607.459387  12500.0   7436
# tx       13159.645441  11600.0  36104
# ga       12949.075310  11400.0  27141
# ne       12674.765640  11600.0   3213
# hi       12176.058468  11750.0    992
# ut       12156.419711  10100.0   1451
# az       11574.705925  10400.0   6903
# or       11500.215517  10900.0    928
# ny       11322.425546   9900.0   4533
# ...

# %% [markdown]
# #### Налоги в штате на продажу автомобилей

# %%
tax_rates = {
    'al': {'tax_rate': 0.02, 'gdp': 229.87},
    'ak': {'tax_rate': 0.0, 'gdp': 59.84},
    'az': {'tax_rate': 0.056, 'gdp': 392.19},
    'ar': {'tax_rate': 0.065, 'gdp': 139.65},
    'ca': {'tax_rate': 0.0725, 'gdp': 3144.88},
    'co': {'tax_rate': 0.029, 'gdp': 417.03},
    'ct': {'tax_rate': 0.0635, 'gdp': 280.58},
    'de': {'tax_rate': 0.0, 'gdp': 78.54},
    'fl': {'tax_rate': 0.06, 'gdp': 1111.87},
    'ga': {'tax_rate': 0.04, 'gdp': 633.82},
    'hi': {'tax_rate': 0.04, 'gdp': 97.28},
    'id': {'tax_rate': 0.06, 'gdp': 91.01},
    'il': {'tax_rate': 0.0625, 'gdp': 933.66},
    'in': {'tax_rate': 0.07, 'gdp': 427.29},
    'ia': {'tax_rate': 0.06, 'gdp': 204.92},
    'ks': {'tax_rate': 0.065, 'gdp': 168.76},
    'ky': {'tax_rate': 0.06, 'gdp': 232.89},
    'la': {'tax_rate': 0.0445, 'gdp': 251.52},
    'me': {'tax_rate': 0.055, 'gdp': 70.04},
    'md': {'tax_rate': 0.06, 'gdp': 470.78},
    'ma': {'tax_rate': 0.0625, 'gdp': 637.36},
    'mi': {'tax_rate': 0.06, 'gdp': 538.78},
    'mn': {'tax_rate': 0.06875, 'gdp': 403.27},
    'ms': {'tax_rate': 0.07, 'gdp': 118.82},
    'mo': {'tax_rate': 0.04225, 'gdp': 326.29},
    'mt': {'tax_rate': 0.0, 'gdp': 56.12},
    'ne': {'tax_rate': 0.055, 'gdp': 117.45},
    'nv': {'tax_rate': 0.0685, 'gdp': 183.38},
    'nh': {'tax_rate': 0.0, 'gdp': 83.95},
    'nj': {'tax_rate': 0.06625, 'gdp': 642.99},
    'nm': {'tax_rate': 0.0513, 'gdp': 104.68},
    'ny': {'tax_rate': 0.04, 'gdp': 1949.07},
    'nc': {'tax_rate': 0.0475, 'gdp': 645.25},
    'nd': {'tax_rate': 0.05, 'gdp': 58.94},
    'oh': {'tax_rate': 0.0575, 'gdp': 750.46},
    'ok': {'tax_rate': 0.045, 'gdp': 222.85},
    'or': {'tax_rate': 0.0, 'gdp': 259.29},
    'pa': {'tax_rate': 0.06, 'gdp': 813.99},
    'ri': {'tax_rate': 0.07, 'gdp': 63.63},
    'sc': {'tax_rate': 0.06, 'gdp': 253.57},
    'sd': {'tax_rate': 0.045, 'gdp': 62.02},
    'tn': {'tax_rate': 0.07, 'gdp': 393.68},
    'tx': {'tax_rate': 0.0625, 'gdp': 1886.92},
    'ut': {'tax_rate': 0.0485, 'gdp': 193.57},
    'vt': {'tax_rate': 0.06, 'gdp': 34.95},
    'va': {'tax_rate': 0.043, 'gdp': 553.66},
    'wa': {'tax_rate': 0.065, 'gdp': 643.27},
    'wv': {'tax_rate': 0.06, 'gdp': 77.73},
    'wi': {'tax_rate': 0.05, 'gdp': 363.92},
    'wy': {'tax_rate': 0.04, 'gdp': 43.42},
    'unknown': {'tax_rate': 0.05875, 'gdp': 252.545}
}

# %%
state_data = research.groupby(['state'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)

# %%
state_stats = pd.DataFrame(tax_rates).T.reset_index()
state_stats.columns = ['state', 'tax_rate', 'gdp']

# %%
state_data = state_data.merge(state_stats, on='state')

# %%
sns.regplot(data = state_data, x = 'tax_rate', y = 'mean')

plt.show()

# %%
sns.regplot(data = state_data, x = 'gdp', y = 'median')

plt.show()

# %% [markdown]
# Наверное я пытаюсь найти связь там, где ее нет...
#
# Стоит учесть, что данные из 2015 года, а моя информация по налогам и GDP из 2021 года

# %% [markdown]
# ### Зависимость цены от состояния

# %%
sns.scatterplot(data = research, x = 'condition', y = 'sellingprice', alpha = 0.002)

plt.show()

# %%
sns.lineplot(data = research, x = 'condition', y = 'sellingprice')

plt.show()

# %% [markdown]
# Чем лучше состояние, тем дороже можно продать машину

# %% [markdown]
# ### Зависимость цены от пробега

# %% [markdown]
# Сначала мне интересна зависимость состояния от пробега.

# %%
sns.lineplot(data = research.query('odometer < 200000 and condition > 0'), x = 'condition', y = 'odometer')
# Out:
# <AxesSubplot:xlabel='condition', ylabel='odometer'>

# %% [markdown]
# Еще одну метрику можно попробовать расчитать - насколько активно автомобилем пользовались.

# %%
def car_age(row):
    production_year = row['year']
    age = 2016-production_year
    return age

# %%
research['car_age'] = research.apply(car_age, axis =1)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/2642605190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['car_age'] = research.apply(car_age, axis =1)

# %%
def usage_calculator(row):
    age = row['car_age']
    odo = row['odometer']
    return(odo/age)

# %%
research['time_delta'] = research.apply(usage_calculator, axis = 1)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/2660785870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['time_delta'] = research.apply(usage_calculator, axis = 1)

# %%
research['usage'] = research.apply(usage_calculator, axis = 1)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/1545917007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['usage'] = research.apply(usage_calculator, axis = 1)

# %%
sns.lineplot(data = research, x = 'sellingprice', y = 'usage')

plt.show()

# %%
sns.lineplot(data = research.query('odometer < 200000 and condition > 0'), x = 'sellingprice', y = 'odometer')

plt.show()

# %% [markdown]
# Метрику нужно будет докрутить конечно, но суть понятна

# %% [markdown]
# ### Зависимость цены от цвета

# %%
research.groupby(['color'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                    mean   median  count
# color
# unknown    17926.340296  15900.0  20106
# charcoal   16666.583548  13800.0    389
# black      15499.045687  13600.0  87115
# off-white  15375.723535  13700.0   1143
# brown      15280.321617  13900.0   5320
# white      14718.716693  13200.0  84149
# gray       13931.332654  12500.0  65284
# red        12672.997074  11600.0  34514
# lime       12667.857143   8100.0     14
# orange     12575.836096  10750.0   1629
# yellow     12276.276813  10100.0    979
# purple     11937.142400  12000.0   1250
# burgundy   11881.777447  11400.0   7059
# silver     11762.329907  10600.0  65667
# blue       11419.240127  10500.0  40237
# pink       10807.812500   8850.0     32
# beige       9401.183823   7600.0   7257
# turquoise   8489.765027   7400.0    183
# green       8323.329694   5600.0   8975
# gold        8302.543989   6000.0   8934

# %% [markdown]
# Есть острое желание также как и с салоном поступить, т.е. упростить всю эту гамму цветов.

# %% [markdown]
# Пока оставим как есть

# %% [markdown]
# ### Зависимость цены от салона

# %%
research.groupby(['interior'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                   mean   median   count
# interior
# brown     20235.597096  18600.0    6818
# black     15680.215374  13800.0  192442
# beige     13341.925637  12000.0   46878
# tan       12343.331153  10800.0   34709
# other     12117.865362   8900.0   18546
# gray      11002.863259   9900.0  140843

# %% [markdown]
# Никогда бы не подумал, что коричневый салон в таком почете.

# %% [markdown]
# ### Зависимость цены от продавца

# %%
research.groupby(['sold_by_bank'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                       mean   median   count
# sold_by_bank
# unknown       13730.298226  12300.0  294823
# bank          13312.236636  11800.0  145413

# %% [markdown]
# Банки продают машины чуточку дешевле.

# %%
research.groupby(['sold_by_dealer'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                         mean   median   count
# sold_by_dealer
# dealer          17777.173171  16600.0   81971
# unknown         12634.690293  11200.0  358265

# %% [markdown]
# А вот дилеры продают существенно дороже.
#
# Над этим признаком еще можно будет поработать

# %%
def is_leased(row):
    seller = str(row['seller']).lower()
    pattern = re.compile(r'leasing|lease')
    if re.search(pattern, seller):
        return 'leased'
    else:
        return 'unknown'

# %%
research['leased'] = research.apply(is_leased, axis = 1)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/2062406228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['leased'] = research.apply(is_leased, axis = 1)

# %%
research.groupby(['leased'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                  mean   median   count
# leased
# leased   16523.862517  14100.0   23552
# unknown  13426.505385  12000.0  416684

# %%
def sold_by_renter(row):
    seller = str(row['seller']).lower()
    pattern = re.compile(r'avis|hertz|enterprise|sixt|fox|rent|ace|np|u-save|rent-a-wreck')
    if re.search(pattern, seller):
        return 'renter'
    else:
        return 'unknown'

# %%
research['renter'] = research.apply(sold_by_renter, axis = 1)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/862724649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['renter'] = research.apply(sold_by_renter, axis = 1)

# %%
research.groupby(['renter'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                  mean   median   count
# renter
# renter   15605.278120  13600.0   55922
# unknown  13299.285524  11800.0  384314

# %%
def sold_by_any_dealer(row):
    make = row['make']
    seller = str(row['seller']).lower()
    seller = seller.split()
    for i in seller:
        if i in all_makes:
            return 'any_dealer'

# %%
research['sold_by_any_dealer'] = research.apply(sold_by_any_dealer, axis = 1)
research['sold_by_any_dealer'] = research['sold_by_any_dealer'].fillna(0)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/1552487873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['sold_by_any_dealer'] = research.apply(sold_by_any_dealer, axis = 1)
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/1552487873.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['sold_by_any_dealer'] = research['sold_by_any_dealer'].fillna(0)

# %%
research.groupby(['sold_by_any_dealer'])['sellingprice'].agg(['mean','median', 'count']).sort_values(by = 'mean', ascending = False)
# Out:
#                             mean   median   count
# sold_by_any_dealer
# any_dealer          15103.335441  14000.0  136459
# 0                   12913.400057  11500.0  303777

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(research.drop('vin', axis = 1).corr(), vmin=-1, vmax=1, cmap='coolwarm', linewidths=1)

plt.show()

# %% [markdown]
# В целом видно, что есть ряд критериев, которые помогают нам чуть лучше определить стоимость машины, в зависимости от ее признаком.
#
# На первом этапе мы пройдемся и попробуем сделать общую модель для всех машин.
#
# Затем результат можно будет улучшив, сделав несколько индивидуальных моделей для конкретных популярных марок и моделей.

# %% [markdown]
# ## Создание дополнительных признаков

# %% [markdown]
# ### Сегмент авто

# %%
def make_segment(row):
    make = row['make']
    if make in luxury:
        return 'luxury'
    elif make in premium:
        return 'premium'
    elif make in sub_premium:
        return 'sub_premium'
    else:
        return 'regular'

# %%
def brand_price_groups(row):
    make = row['make']
    try:
        price = brand_median[make]
    except:
        price = 34000
    if price > 100000:
        return 'group_1'
    elif price <= 100000 and price >50000:
        return 'group_2'
    elif price <=50000 and price >40000:
        return 'group_3'
    elif price <=40000 and price >30000:
        return 'group_4'
    elif price <=30000 and price >20000:
        return 'group_5'
    elif price <=20000 and price >15000:
        return 'group_6'
    elif price <=15000 and price >12500:
        return 'group_7'
    elif price <=12500 and price >10000:
        return 'group_8'
    else:
        return 'group_9'

# %% [markdown]
# ### Состояние машины

# %%
def condition_groups(row):
    condition = row['condition']
    if condition == 0:
        return 'unknown'
    elif condition >=1 and condition < 2:
        return 'group_1'
    elif condition >=2 and condition < 3:
        return 'group_2'
    elif condition >=3 and condition < 4:
        return 'group_3'
    elif condition >=4 and condition < 5:
        return 'group_4'
    else:
        return 'group_5'

# %% [markdown]
# ### Возраст авто и его группа

# %%
def car_age_group(row):
    age = row['car_age']
    if age == 0:
        return 'group_0'
    elif age == 1:
        return 'group_1'
    elif age == 2 or age == 3:
        return 'group_2'
    elif age >3 and age <=5:
        return 'group_3'
    elif age >5 and age <=10:
        return 'group_4'
    elif age >10 and age <=15:
        return 'group_5'
    else:
        return 'group_6'

# %% [markdown]
# ### Активность использования

# %%
def usage_calculator(row):
    age = row['car_age']
    odo = row['odometer']
    return(odo/age)

# %%
research['usage_groups'] = pd.qcut(research['usage'], 8)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/3851606502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research['usage_groups'] = pd.qcut(research['usage'], 8)

# %%
research.groupby('usage_groups')['sellingprice'].mean()
# Out:
# usage_groups
# (0.0375, 5840.0]         19389.005742
# (5840.0, 7732.5]         16368.170086
# (7732.5, 9281.5]         14264.012631
# (9281.5, 10820.528]      12727.184688
# (10820.528, 12491.5]     11726.536225
# (12491.5, 14577.35]      11182.119267
# (14577.35, 17685.719]    11244.951407
# (17685.719, 499999.5]    11835.158114
# Name: sellingprice, dtype: float64

# %%
def usage_group(row):
    pass

# %% [markdown]
# ### Популярность авто

# %%
def brand_popularity_groups(row):
    make = row['make']
    try:
        sellers = brand_popularity[make]
    except:
        return 'unknown'
    if sellers > 30000:
        return 'group_1'
    elif sellers <= 30000 and sellers >20000:
        return 'group_2'
    elif sellers <=20000 and sellers >10000:
        return 'group_3'
    elif sellers <=10000 and sellers >5000:
        return 'group_4'
    elif sellers <=5000 and sellers >1000:
        return 'group_5'
    else:
        return 'group_6'

# %%
def model_popularity_groups(row):
    make = row['make']
    model = row['model']
    try:
        sellers = model_popularity[make][model]
    except:
        return 'unknown'
    if sellers > 10000:
        return 'group_1'
    elif sellers <= 10000 and sellers >6000:
        return 'group_2'
    elif sellers <=6000 and sellers >4000:
        return 'group_3'
    elif sellers <=4000 and sellers >2000:
        return 'group_4'
    elif sellers <=2000 and sellers >1000:
        return 'group_5'
    else:
        return 'group_6'

# %% [markdown]
# ## Подготовка признакового пространства

# %%
data = pd.read_csv('/Users/inikiforov/Python/practicum/workshop1/train.csv')
test = pd.read_csv('/Users/inikiforov/Python/practicum/workshop1/test.csv')

# %% [markdown]
# ### Создание и кодирование признаков

# %% [markdown]
# Список признаков, которые нужно создать.

# %%
all_data = data.append(test)
all_data.reset_index(inplace = True)
# Out:
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/359912293.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = data.append(test)

# %%
def add_new_features(data_source):
    data = data_source
    
    print('Starting data preparation...')
    print('Preparing make, make segments and brand price groups')
    
    data['make'] = data['make'].str.lower()
    data['make'] = data['make'].map(car_brands_dict).fillna(combined['make'])
    data['make'] = data['make'].fillna('unknown')
    
    data['make_segment'] = data.apply(make_segment, axis = 1)
    data['brand_price_groups'] = data.apply(brand_price_groups, axis = 1)
    
    print('Preparing year_date, car_age and car_age_groups')
    data['year_date'] = pd.to_datetime(data['year'], format='%Y')
    data['car_age'] = data.apply(car_age, axis = 1)
    data['car_age_group'] = data.apply(car_age_group, axis = 1)
    
    print('Preparing model, trim, awd and special')
    data['model'] = data['model'].str.lower()
    data['model'] = data['model'].fillna('unknown')
    
    data['trim'] = data['trim'].str.lower()
    data['trim'] = data['trim'].fillna('unknown')
    
    data['awd'] = data.apply(is_4x4, axis = 1)
    data['special'] = data.apply(is_special, axis = 1)
    data['engine'] = data.apply(what_engine, axis = 1)
    
    print('Working with bodies')
    data['body'] = data['body'].str.lower()
    data['body'] = data.apply(is_pickup, axis = 1)
    data['body'] = data.apply(is_coupe, axis = 1)
    data['body'] = data.apply(is_van, axis = 1)
    data['body'] = data.apply(split_return, axis = 1)
    data['body'] = data['body'].fillna('unknown')
    
    print('Transmission and state')
    data['transmission'] = data['transmission'].fillna('automatic')
    data['state'] = data['state'].fillna('unknown')
    
    print('Working on condition and condition_groups')
    data['condition'] = data['condition'].fillna(0)
    data['condition_groups'] = data.apply(condition_groups, axis = 1)
    
    print('Now odometer, color, interior types')
    data['odometer'] = data['odometer'].fillna(data['odometer'].median())
    data['color'] = data['color'].replace('—','unknown')
    data['color'] = data['color'].fillna('unknown')
    data['interior'] = data['interior'].replace('—','unknown')
    data['interior'] = data['interior'].fillna('unknown')
    data['interior'] = data.apply(simplify_interior, axis = 1)
    
    print('Seller types')
    data['sold_by_dealer'] = data.apply(sold_by_dealer, axis = 1)
    data['sold_by_bank'] = data.apply(sold_by_bank, axis = 1)
    data['saledate_converted'] = data['saledate'].apply(convert_to_datetime)
    
    print('Sale date and sale month')
    data['sale_day'] = data['saledate_converted'].dt.dayofweek
    data['sale_day'] = data['sale_day'].map(days_map)
    
    data['sale_month'] = data['saledate_converted'].dt.month
    data['sale_month'] = data['sale_month'].map(month_map)
    
    
    data['state'] = data.apply(state_cleaner, axis = 1)
    
    print('Usage intensity and usage groups')
    data['usage'] = data.apply(usage_calculator, axis = 1)
    data['usage_groups'] = pd.qcut(data['usage'], 8)
    data['usage_groups'] = data['usage_groups'].astype(str)
    
    print('Brand popularity and model popularity')
    data['brand_popularity_group'] = data.apply(brand_popularity_groups, axis = 1)
    data['model_popularity_group'] = data.apply(model_popularity_groups, axis = 1)
    
    print('Other variables')
    data['volume'] = data.apply(get_volume, axis = 1)
    data['renter'] = data.apply(sold_by_renter, axis = 1)
    data['leased'] = data.apply(is_leased, axis = 1)
    data['sold_by_any_dealer'] = data.apply(sold_by_any_dealer, axis = 1)
    data['sold_by_any_dealer'] = data['sold_by_any_dealer'].fillna('unknown')
    data['average_model_price'] = data.apply(average_price, axis = 1)
    
    
    print('All done')
    
    return data

# %%
features_to_drop = [
    'year',
    'model',
    'trim',
    'seller',
    'saledate',
    'saledate_converted',
    'state',
    'year_date',
    'make',
    'body',
    'transmission',
    'vin',
    'color',
    'interior',
    'sale_month',
    'sale_day',
    'make_segment',
    'brand_price_groups',
    'condition_groups',
    'condition',
    'car_age',
    'car_age_group',
    'usage',
    'usage_groups',
    'brand_popularity_group',
    'model_popularity_group',
    'engine',
    'special',
    'awd',
    'sold_by_dealer',
    'sold_by_bank',
    'renter',
    'leased',
    'sold_by_any_dealer'
    
]

# %%
features_to_ohe = [
    'body',
    'transmission',
    'color',
    'interior',
    'sale_day',
    'sale_month',
    'make_segment',
    'brand_price_groups',
    'condition_groups',
    'car_age_group',
    'usage_groups',
    'brand_popularity_group',
    'model_popularity_group',
    'engine',
    'special',
    'awd',
    'sold_by_dealer',
    'sold_by_bank',
    'renter',
    'leased',
    'sold_by_any_dealer'
]

# %%
def prepare_data(input_data):
    
    result_data = input_data
    
    result_data = add_new_features(result_data)
    dummies = pd.get_dummies(result_data[features_to_ohe], drop_first = True)
    result_data = result_data.join(dummies)
    result_data = result_data.drop(features_to_drop, axis = 1)
    result_data = result_data.drop('index', axis = 1)
    
    return result_data

# %%
data_encoded = prepare_data(all_data)
# Out:
# Starting data preparation...
# Preparing make, make segments and brand price groups
# Preparing year_date, car_age and car_age_groups
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/1072321013.py in <module>
# ----> 1 data_encoded = prepare_data(all_data)
#
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/2904383269.py in prepare_data(input_data)
#       3     result_data = input_data
#       4
# ----> 5     result_data = add_new_features(result_data)
#       6     dummies = pd.get_dummies(result_data[features_to_ohe], drop_first = True)
#       7     result_data = result_data.join(dummies)
#
# /var/folders/hd/rx27h3px53j16p51j58vw6jr0000gn/T/ipykernel_13169/2498978721.py in add_new_features(data_source)
#      15     data['year_date'] = pd.to_datetime(data['year'], format='%Y')
# ...

# %%
data_encoded.head(10)
# Out:
#    odometer  sellingprice  volume  body_coupe  body_hatchback  body_nan  \
# 0  111041.0       12500.0     NaN           0               0         0
# 1   31034.0       14500.0     NaN           0               0         0
# 2   35619.0        9100.0     2.0           0               0         0
# 3  131301.0       13300.0     NaN           0               0         0
# 4  127709.0        1300.0     NaN           0               0         0
# 5   14894.0       22600.0     NaN           0               0         0
# 6  114587.0        5900.0     NaN           0               0         1
# 7   26273.0       15200.0     NaN           0               0         0
# 8  182624.0         700.0     NaN           0               0         0
# 9  149364.0         325.0     NaN           0               0         0
#
#    body_pickup  body_sedan  body_suv  body_van  ...  engine_v6  engine_v8  \
# 0            0           0         1         0  ...          0          0
# ...

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550294 entries, 0 to 550293
# Data columns (total 99 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   odometer                             550294 non-null  float64
#  1   sellingprice                         440236 non-null  float64
#  2   volume                               49319 non-null   float64
#  3   body_coupe                           550294 non-null  uint8
#  4   body_hatchback                       550294 non-null  uint8
#  5   body_nan                             550294 non-null  uint8
#  6   body_pickup                          550294 non-null  uint8
#  7   body_sedan                           550294 non-null  uint8
#  8   body_suv                             550294 non-null  uint8
#  9   body_van                             550294 non-null  uint8
#  10  body_wagon                           550294 non-null  uint8
# ...

# %% [markdown]
# ### Разделение выборки

# %%
train_set = data_encoded.loc[:440235]
test_set = data_encoded.loc[440236:]

# %%
targets = train_set['sellingprice']
features = train_set.drop('sellingprice', axis = 1)
test_set = test_set.drop('sellingprice', axis = 1)

# %%
features_train, features_valid, targets_train, targets_valid = train_test_split(
    features, targets, test_size=0.25, random_state=12345)

# %% [markdown]
# ### Наивная модель

# %%
train_set['sellingprice'].mean()
# Out:
# 13592.20958758484

# %%
naive_predictions = []
for i in range(len(predictions_valid)):
    naive_predictions.append(13322.25)

# %%
mse = mean_squared_error(naive_predictions, predictions_valid) ** 0.5
mae = mean_absolute_error(naive_predictions, predictions_valid)
mape = mean_absolute_percentage_error(naive_predictions, predictions_valid)
print("RMSE наивной модели на валидационной выборке:", mse)
print("MAE наивной модели на валидационной выборке:", mae)
print("MAPE наивной модели на валидационной выборке:", mape)
# Out:
# RMSE наивной модели на валидационной выборке: 9214.959922876033
# MAE наивной модели на валидационной выборке: 6805.381114763359
# MAPE наивной модели на валидационной выборке: 0.5108282095564458

# %% [markdown]
# ### HistGradientBoosting

# %%
reg = HistGradientBoostingRegressor(random_state = 12345)
reg.fit(features_train, targets_train)
# Out:
# HistGradientBoostingRegressor(random_state=12345)

# %%
predictions_valid = reg.predict(features_valid)

# %%
mse = mean_squared_error(targets_valid, predictions_valid) ** 0.5
mae = mean_absolute_error(targets_valid, predictions_valid)
mape = mean_absolute_percentage_error(targets_valid, predictions_valid)
print("RMSE градиентного бустинга на валидационной выборке:", mse)
print("MAE градиентного бустинга на валидационной выборке:", mae)
print("MAPE градиентного бустинга на валидационной выборке:", mape)
# Out:
# RMSE градиентного бустинга на валидационной выборке: 3817.1901051743534
# MAE градиентного бустинга на валидационной выборке: 2430.017688928494
# MAPE градиентного бустинга на валидационной выборке: 0.41019011248978693

# %% [markdown]
# В документации к GradientBoostingRegressor прочитал про HistGradientBoosting. Сразу же получилось улучшить результат на той же предобработке, что и раньше. Теперь попробуем реализовать кросс-валидацию и подобрать гиперпараметры.

# %% [markdown]
# #### feature importance

# %%
result = permutation_importance(reg, features_train, targets_train, n_repeats=1, random_state=12345)

feature_importances = result.importances_mean

feature_importance_dict = {}
for feature_name, importance in zip(features_train.columns, feature_importances):
    feature_importance_dict[feature_name] = importance

sorted_feature_importances = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_feature_importances = sorted_feature_importances[::-1]
#sorted_feature_importances = sorted_feature_importances[20::]

top_features = sorted_feature_importances

all_features, importance = zip(*top_features)

fig, ax = plt.subplots(figsize=(30, 20))
ax.barh(all_features, importance)

ax.set_xlabel('Importance')
ax.set_ylabel('Features')
ax.set_title('Feature Importance')

plt.show()

# %%
counter = 0
top_features_list = []
while counter<20:
    top_features_list.append(top_features[::-1][counter][0])
    counter +=1

# %%
top_features_list
# Out:
# ['make_segment_regular',
#  'make_segment_sub_premium',
#  'odometer',
#  'body_sedan',
#  'body_pickup',
#  'brand_price_groups_group_5',
#  'condition_groups_group_4',
#  'model_popularity_group_group_6',
#  'car_age_group_group_5',
#  'body_suv',
#  'body_hatchback',
#  'special_unknown',
#  'brand_popularity_group_group_3',
#  'car_age_group_group_2',
#  'brand_price_groups_group_8',
#  'car_age_group_group_3',
#  'model_popularity_group_group_3',
#  'model_popularity_group_group_5',
#  'brand_price_groups_group_9',
#  'volume']

# %%
unimportant_features = []

for i in features.columns:
    if i in top_features_list:
        pass
    else:
        unimportant_features.append(i)

# %%
## Этот блок может быть использован для исключения невлияющих фич
## Из экспериментов я понял, что исключение фич положительно не влияет на результат
#features = features.drop(unimportant_features, axis =1)
#test_set = test_set.drop(unimportant_features, axis =1)

#features_train, features_valid, targets_train, targets_valid = train_test_split(
#    features, targets, test_size=0.25, random_state=12345)

# %% [markdown]
# #### Подбор гиперпараметров для HistGBR

# %%
## Здесь можно подбирать гиперпараметры
## Сейчас оставил последние, которые хорошо работали

parameter_grid = {
                 'max_depth': [16, 24],
                 'max_iter': [1500],
                 'learning_rate': [0.1],
                 "loss": ["squared_error"],
                'random_state':[12345],
                 }


boost = HistGradientBoostingRegressor()

cross_validation = KFold(n_splits=5)

grid_search = GridSearchCV(boost,
                           scoring='neg_mean_absolute_percentage_error',
                           param_grid=parameter_grid,
                           cv=cross_validation,
                           verbose=1,
                           n_jobs = -1
                          )

grid_search.fit(features, targets)
model = grid_search
parameters = grid_search.best_params_

print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Best score: -0.2735370111828018
# Best parameters: {'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 24, 'max_iter': 1500, 'random_state': 12345}

# %%
params = {'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 24, 'max_iter': 1500, 'random_state': 12345}
model = HistGradientBoostingRegressor(**params)
model.fit(features, targets)
# Out:
# HistGradientBoostingRegressor(max_depth=24, max_iter=1500, random_state=12345)

# %% [markdown]
# ### catboost

# %% [markdown]
# #### Переподготовим датасет

# %% [markdown]
# Судя по тому, что я прочитал про catboost он лучше работает не с OHE, а с просто сырыми категориальными данными. Особенно когда их много. Поэтому он отлично подойдет к нашей задаче.

# %%
## Исключена часть, где мы делаем OHE

def prepare_data_catboost(input_data):
    
    result_data = input_data
    
    result_data = add_new_features(result_data)
    result_data = result_data.drop(features_to_drop_catboost, axis = 1)
    result_data = result_data.drop('index', axis = 1)
    
    return result_data

# %%
features_to_drop_catboost = [
    'year',
    'model',
    'trim',
    'seller',
    'saledate',
    'saledate_converted',
    'state',
    'year_date',
    'make',
    #'body',
    #'transmission',
    'vin',
    #'color',
    #'interior',
    'sale_month',
    'sale_day',
    #'make_segment',
    #'brand_price_groups',
    #'condition_groups',
    #'condition',
    #'car_age',
    #'car_age_group',
    #'usage',
    #'usage_groups',
    #'brand_popularity_group',
    #'model_popularity_group',
    #'engine',
    #'special',
    'volume'
    
]

# %%
data_encoded_catboost = prepare_data_catboost(all_data)
# Out:
# Starting data preparation...
# Preparing make, make segments and brand price groups
# Preparing year_date, car_age and car_age_groups
# Preparing model, trim, awd and special
# Working with bodies
# Transmission and state
# Working on condition and condition_groups
# Now odometer, color, interior types
# Seller types
# Sale date and sale month
# Usage intensity and usage groups
# Brand popularity and model popularity
# Other variables
# All done

# %%
train_set = data_encoded_catboost.loc[:440235]
test_set = data_encoded_catboost.loc[440236:]

# %%
targets_cat = train_set['sellingprice']
features_cat = train_set.drop('sellingprice', axis = 1)
test_set_cat = test_set.drop('sellingprice', axis = 1)

# %%
features_train_cat, features_valid_cat, targets_train_cat, targets_valid_cat = train_test_split(
    features_cat, targets_cat, test_size=0.25, random_state=12345)

# %%
features_train_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330177 entries, 187081 to 217570
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   body                    330177 non-null  object
#  1   transmission            330177 non-null  object
#  2   condition               330177 non-null  float64
#  3   odometer                330177 non-null  float64
#  4   color                   330177 non-null  object
#  5   interior                330177 non-null  object
#  6   make_segment            330177 non-null  object
#  7   brand_price_groups      330177 non-null  object
#  8   car_age                 330177 non-null  int64
#  9   car_age_group           330177 non-null  object
#  10  awd                     330177 non-null  object
#  11  special                 330177 non-null  object
#  12  engine                  330177 non-null  object
# ...

# %%
cat_features_list = [0, 1, 4, 5, 6, 7, 9, 10, 11, 12, 13, 14, 15, 17, 18, 19, 20, 21, 22]

# %% [markdown]
# #### Обучение модели

# %%
boost = CatBoostRegressor(depth = 16, iterations = 1200, learning_rate = 0.1, random_seed = 12345, 
                          cat_features=cat_features_list,
                          od_type = 'Iter',
                          od_wait = 20,
                          eval_metric = 'MAPE'
                          
                         )

# %%
boost.fit(features_train_cat, targets_train_cat, 
          verbose = True, 
          eval_set = (features_valid_cat, targets_valid_cat),
          #logging_level = 'Silent',
          #plot = True,
         )
# Out:
# 0:	learn: 1.6948539	test: 1.7998761	best: 1.7998761 (0)	total: 1.53s	remaining: 30m 36s
# 1:	learn: 1.5571413	test: 1.6654483	best: 1.6654483 (1)	total: 2.87s	remaining: 28m 39s
# 2:	learn: 1.4294107	test: 1.5391953	best: 1.5391953 (2)	total: 4.13s	remaining: 27m 30s
# 3:	learn: 1.3167374	test: 1.4245673	best: 1.4245673 (3)	total: 5.25s	remaining: 26m 10s
# 4:	learn: 1.2115871	test: 1.3178594	best: 1.3178594 (4)	total: 6.49s	remaining: 25m 49s
# 5:	learn: 1.1205119	test: 1.2263516	best: 1.2263516 (5)	total: 7.58s	remaining: 25m 8s
# 6:	learn: 1.0368223	test: 1.1458588	best: 1.1458588 (6)	total: 8.75s	remaining: 24m 50s
# 7:	learn: 0.9599331	test: 1.0719205	best: 1.0719205 (7)	total: 9.81s	remaining: 24m 22s
# 8:	learn: 0.8919218	test: 1.0025026	best: 1.0025026 (8)	total: 11s	remaining: 24m 20s
# 9:	learn: 0.8265694	test: 0.9381696	best: 0.9381696 (9)	total: 12.2s	remaining: 24m 8s
# 10:	learn: 0.7703339	test: 0.8810791	best: 0.8810791 (10)	total: 13.4s	remaining: 24m 4s
# ...

# %%
predictions_valid_cat = boost.predict(features_valid_cat)

# %%
## Этот кусок кода здесь потому, что на начальном этапе модель обучалась на features_train_cat и targets_train_cat
## Потом я делал переобучение на полный features_cat и targets_cat
mse = mean_squared_error(targets_valid_cat, predictions_valid_cat) ** 0.5
mae = mean_absolute_error(targets_valid_cat, predictions_valid_cat)
mape = mean_absolute_percentage_error(targets_valid_cat, predictions_valid_cat)
print("RMSE cat бустинга на валидационной выборке:", mse)
print("MAE cat бустинга на валидационной выборке:", mae)
print("MAPE cat бустинга на валидационной выборке:", mape)
# Out:
# RMSE cat бустинга на валидационной выборке: 2367.141765552748
# MAE cat бустинга на валидационной выборке: 1437.52266609448
# MAPE cat бустинга на валидационной выборке: 0.2890969388317214

# %%
boost = CatBoostRegressor(depth = 16, iterations = 1200, learning_rate = 0.1, random_seed = 12345, 
                          cat_features=cat_features_list,
                          od_type = 'Iter',
                          od_wait = 50,
                          eval_metric = 'MAPE'
                          
                         )

# %%
boost.fit(features_cat, targets_cat, 
          plot = True
         )
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 1.7217736	total: 1.29s	remaining: 25m 51s
# 1:	learn: 1.5831222	total: 2.65s	remaining: 26m 24s
# 2:	learn: 1.4554832	total: 3.89s	remaining: 25m 53s
# 3:	learn: 1.3422794	total: 5.06s	remaining: 25m 12s
# 4:	learn: 1.2410143	total: 6.23s	remaining: 24m 50s
# 5:	learn: 1.1476108	total: 7.49s	remaining: 24m 51s
# 6:	learn: 1.0625652	total: 8.85s	remaining: 25m 8s
# 7:	learn: 0.9834236	total: 9.98s	remaining: 24m 47s
# 8:	learn: 0.9175283	total: 11.2s	remaining: 24m 40s
# 9:	learn: 0.8553977	total: 12.4s	remaining: 24m 36s
# 10:	learn: 0.8002245	total: 13.7s	remaining: 24m 41s
# 11:	learn: 0.7489776	total: 14.9s	remaining: 24m 36s
# 12:	learn: 0.7042608	total: 16s	remaining: 24m 24s
# 13:	learn: 0.6612996	total: 17.2s	remaining: 24m 20s
# 14:	learn: 0.6218733	total: 18.5s	remaining: 24m 18s
# 15:	learn: 0.5866699	total: 19.7s	remaining: 24m 21s
# 16:	learn: 0.5540786	total: 21s	remaining: 24m 18s
# ...

# %% [markdown]
# ## Output

# %% [markdown]
# ### HistGradientBoostingRegressor Output

# %%
output = model.predict(test_set)
output_df = pd.DataFrame()
output_df['vin'] = test['vin']
output_df['sellingprice'] = output
output_df.to_csv('output.csv', index=False)

# %% [markdown]
# ### catboost Output

# %%
output = boost.predict(test_set_cat)
output_df = pd.DataFrame()
output_df['vin'] = test['vin']
output_df['sellingprice'] = output
output_df.to_csv('output_cat.csv', index=False)
